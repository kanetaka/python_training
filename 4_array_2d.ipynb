# %% [markdown]
# # 第4章 2次元配列

# %% [markdown]
# ### 行と列の覚え方

# %% [markdown]
# ### 2次元配列aの内容をfor文を使って表示して下さい．

# %%
a = [
    [1, 2, 3],
    [4, 5, 6],
]


# ここに回答を記入して下さい．

# %% [markdown]
# ### NumPyで2次元配列bを作成し，for文を使って表示して下さい．

# %%
import numpy as np

# ここに回答を記入して下さい．

# %% [markdown]
# ### DataFrame変数dfをカラム名 (変数column) をつけて作成して下さい．

# %%
import pandas as pd

data = [["りんご", 76, 2],
        ["ごま", 230, 1],
        ["マグロ", 580, 10]]
columns = ["品名", "値段", "個数"]

# ここに回答を記入して下さい．

# %% [markdown]
# ### 行と列の覚え方

# %% [markdown]
# ![miya_180225noroinogyoretsu01.jpg](attachment:miya_180225noroinogyoretsu01.jpg)

# %% [markdown]
# ### for文を使って行ごとに表示して下さい．
# ヒント：iterrows()関数を使う

# %%
# ここに回答を記入して下さい．

# %% [markdown]
# ### for文を使って列ごとに表示して下さい．
# ヒント：iteritems()関数を使う

# %%
# ここに回答を記入して下さい．
